# %% [markdown]
# ##### Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %% [markdown]
# `Matplotlib` is a popular Python library for creating `static`, `animated`, or `interactive` `visualizations` in data science, machine learning, and scientific computing. It provides a wide range of tools for constructing various types of plots and charts to help users visualize their data effectively.

# %% [markdown]
# Matplotlib's pyplot are five plots that can create using module

# %% [markdown]
# #### 1. Line Plot
# A line plot is a graphical respresentation of data on a number line.  You can use `plt.plot()` to create line plots

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [4,5,6,9,7,8]
y = [1,2,3,4,5,6]
plt.plot(x,y)
plt.show()

# %% [markdown]
# #### 2. Bar chart
# Bar charts constructed with `plt.bar()`, are commonly used for comparing data across different categories or displaying discrete data.

# %%
y=[1,2,3,4,5]
x=['a','b','c','d','e']
plt.bar(x,y)
plt.xlabel('this is x-axis')
plt.ylabel('this is y-axis')
plt.show()

# %% [markdown]
# #### 3. Scatter Plot
# `plt.scatter()` is used to create scatter plots, which are useful for visualizing individual data points and identifying patterns or clusters in the data.

# %%
x = np.random.rand(25)
y = np.random.rand(25)
colour =np.random.rand(25)
plt.scatter(x,y,c=colour)

# %% [markdown]
# #### 4.Histogram
# `plt.hist()` is used to create histograms, which represent the distribution of a dataset by dividing it into bins and displaying the frequency of data points within each bin.

# %%
x = ['a','b','c','a','v','b','c','e','a']
plt.hist(x)
# Out:
# (array([3., 0., 2., 0., 0., 2., 0., 1., 0., 1.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #### 5. Pie chart
# Pie charts can be created with `plt.pie()`, and they are typically used to display the proportions of various categories within a whole, making it easy to visualize data as a percentage of the total.

# %%
x = [2,3,4,5,6,7]
plt.pie(x)
plt.show()

# %% [markdown]
# ##### Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot.

# %% [markdown]
# ``import matplotlib.pyplot as plt``
#
# ``plt.xlabel('x axis')``
#
# ``plt.ylabel('y axis')``
#
# ``plt.title('this is title')``
#
# ``plt.scatter(x,y)``
#
# ``plt.show()``

# %%
import matplotlib.pyplot as plt
x = np.random.rand(50)
y = np.random.rand(50)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('this is title')
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create sample data
x = np.linspace(0, 10, 100)  # Generate an array of values from 0 to 10
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)
y4 = np.exp(x)

# Create a 2x2 grid of subplots
plt.figure(figsize=(10, 8))  # Set the size of the entire figure

# Subplot 1
plt.subplot(2, 2, 1)
plt.plot(x, y1)
plt.title('Plot 1: sin(x)')

# Subplot 2
plt.subplot(2, 2, 2)
plt.plot(x, y2)
plt.title('Plot 2: cos(x)')

# Subplot 3
plt.subplot(2, 2, 3)
plt.plot(x, y3)
plt.title('Plot 3: tan(x)')

# Subplot 4
plt.subplot(2, 2, 4)
plt.plot(x, y4)
plt.title('Plot 4: exp(x)')

# Adjust the layout to prevent overlap
plt.tight_layout()

# Show the figure with all subplots
plt.show()

# %% [markdown]
# ##### Q3: Why is the subplot() function used? Draw four line plots using the subplot() function. Use the following data:
#
# `import numpy as np`
#
# `For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])`
#
# `For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])`
#
# `For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])`
#
# `For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])`

# %%
plt.figure(figsize=(10, 8))
#for line 1
x1 = np.array([0, 1, 2, 3, 4, 5]) 
y1 = np.array([0, 100, 200, 300, 400, 500])

#For line 2: 
x2 = np.array([0, 1, 2, 3, 4, 5]) 
y2 = np.array([50, 20, 40, 20, 60, 70])

#For line 3: 
x3 = np.array([0, 1, 2, 3, 4, 5]) 
y3 = np.array([10, 20, 30, 40, 50, 60])

#For line 4: 
x4 = np.array([0, 1, 2, 3, 4, 5]) 
y4 = np.array([200, 350, 250, 550, 450, 150])
# subplot line 1
plt.subplot(2,2,1)
plt.plot(x1,y1)
plt.title('line 1')

#subplot line 2
plt.subplot(2,2,2)
plt.plot(x2,y2)
plt.title('line 2')

#subplot line 3
plt.subplot(2,2,3)
plt.plot(x3,y3)
plt.title('line 3')

#subplot line 4
plt.subplot(2,2,4)
plt.plot(x4,y4)
plt.title('line 4')
# Out:
# Text(0.5, 1.0, 'line 4')

# %% [markdown]
# ##### Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %% [markdown]
# `import numpy as np`
#
# `company = np.array(["Apple", "Microsoft", "Google", "AMD"])`
#
# `profit = np.array([3000, 8000, 1000, 10000])`

# %% [markdown]
# - A bar plot, also known as a bar chart or bar graph, is a type of data visualization that uses rectangular bars to represent data values. Each bar's length or height is proportional to the data it represents, making it easy to compare different categories or groups of data

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.barh(company,profit)
plt.ylabel('Comany name')
plt.xlabel('profit')
# Out:
# Text(0.5, 0, 'profit')

# %% [markdown]
# ##### Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# %% [markdown]
# `box1 = np.random.normal(100, 10, 200)`
#
# `box2 = np.random.normal(90, 20, 200)`

# %% [markdown]
# - A box plot, also known as a box-and-whisker plot, is a graphical representation of the distribution of a dataset. It provides a summary of the data's central tendency, spread, and the presence of outliers. A box plot is used to visualize the following statistics of a dataset

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
plt.figure(figsize = (6,4))
# plot box1
plt.subplot(2,2,1)
plt.boxplot(box1,vert = False)
plt.title('Box 1')

#plot box2
plt.subplot(2,2,2)
plt.boxplot(box2,vert = False)
plt.title('Box 2')
# Out:
# Text(0.5, 1.0, 'Box 2')
